# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv')

# %%
data
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
data_html = pd.read_html("http://vincentarelbundock.github.io/Rdatasets/datasets.html")

# %%
data_html
# Out:
# [                                                Package           Item  \
#  0                                                   AER        Affairs
#  1                                                   AER   ArgentinaCPI
#  2                                                   AER      BankWages
#  3                                                   AER  BenderlyZwick
#  4                                                   AER      BondYield
#  ...                                                 ...            ...
#  1710                                                vcd   VisualAcuity
#  1711                                                vcd        VonBort
#  1712                                                vcd     WeldonDice
#  1713                                                vcd     WomenQueue
#  1714  Package Item Title Rows Cols n_binary n_charac...            NaN
#
#                                                    Title   Rows  Cols  \
# ...

# %%
data_json = pd.read_json("")
